# %% [markdown]
# <a href="https://colab.research.google.com/github/ainguyen05/ainguyen05.github.io/blob/main/EDA_Fin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Buổi 4: Đầu tư định lượng cùng Pandas

# %%
# !pip install pandas_datareader
# !pip install yfinance
# !pip install mplfinance
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.5 MB/s eta 0:00:00
# ...

# %%
# !pip install --user yfinance==0.1.36
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.36-py3-none-any.whl size=12274 sha256=7f34d17bfd6b35ac6e5697859af405a9989c67c4a6a89be97d1d71abb220bb62
#   Stored in directory: /root/.cache/pip/wheels/aa/44/ba/0ea9a69f4cce0c2191e54dcadcff129f35a2284b644ca5c200
# Successfully built yfinance
# ...
#   WARNING: The script sample is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
# !pip install yfinance==0.1.87
# Out:
# ...
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.1.36
#     Uninstalling yfinance-0.1.36:
#       Successfully uninstalled yfinance-0.1.36
# ...

# %%
import pandas as pd
# import pandas_datareader.data as web
import matplotlib.pyplot as plt
import mplfinance as mpf
import seaborn as sns
import datetime as dt
# %matplotlib inline

# sửa lỗi tải dữ liệu của pandas_datareader
# from IPython.display import display
import yfinance as yf
# yf.pdr_override()

# %%
end = dt.datetime.now()
start = dt.datetime(2016, 1, 1)
print(f'{start} -> {end}')

# Use yfinance.download to get the data
df = yf.download('AAPL', start=start, end=end)
# Out:
# 2016-01-01 00:00:00 -> 2025-10-25 09:46:19.495546
# /tmp/ipython-input-2477894337.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download('AAPL', start=start, end=end)
# [*********************100%***********************]  1 of 1 completed

# %%
display(df.head())
display(df.tail())
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2016-01-04  23.776178  23.780693  23.020126  23.157795  270597600
# 2016-01-05  23.180365  23.889023  23.112659  23.866455  223164000
# 2016-01-06  22.726730  23.103630  22.539411  22.695134  273829600
# 2016-01-07  21.767557  22.598087  21.763044  22.270841  324377600
# 2016-01-08  21.882662  22.367890  21.837525  22.241506  283192000
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2025-10-20  262.239990  264.380005  255.630005  255.889999  90483000
# 2025-10-21  262.769989  265.290009  261.829987  261.880005  46695900
# 2025-10-22  258.450012  262.850006  255.429993  262.649994  45015300
# 2025-10-23  259.579987  260.619995  258.010010  259.940002  32754900
# 2025-10-24  262.820007  264.130005  259.179993  261.190002  38221700

# %%
df.loc['2024-04-19']
# Out:
# Price   Ticker
# Close   AAPL      1.638236e+02
# High    AAPL      1.652136e+02
# Low     AAPL      1.629101e+02
# Open    AAPL      1.650249e+02
# Volume  AAPL      6.814940e+07
# Name: 2024-04-19 00:00:00, dtype: float64

# %%
df.to_csv('AAPL.csv')
df1 = pd.read_csv('AAPL.csv', index_col=0)

# %%
display(df1)
# Out:
#                          Close                High                 Low  \
# Price
# Ticker                    AAPL                AAPL                AAPL
# Date                       NaN                 NaN                 NaN
# 2016-01-04   23.77617835998535   23.78069307433639  23.020125560934314
# 2016-01-05   23.18036460876465   23.88902327269363  23.112659386942752
# 2016-01-06  22.726730346679688  23.103629776733978  22.539411032061107
# ...                        ...                 ...                 ...
# 2025-10-20    262.239990234375   264.3800048828125   255.6300048828125
# 2025-10-21   262.7699890136719   265.2900085449219   261.8299865722656
# 2025-10-22  258.45001220703125   262.8500061035156  255.42999267578125
# 2025-10-23   259.5799865722656   260.6199951171875    258.010009765625
# 2025-10-24  262.82000732421875   264.1300048828125  259.17999267578125
#
#                           Open     Volume
# Price
# Ticker                    AAPL       AAPL
# ...

# %%
df['Close'].plot(legend=True, figsize=(12,8), title='AAPL', label = 'Close')
# Out:
# <Axes: title={'center': 'AAPL'}, xlabel='Date'>

# %%
df.index
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2025-10-13', '2025-10-14', '2025-10-15', '2025-10-16',
#                '2025-10-17', '2025-10-20', '2025-10-21', '2025-10-22',
#                '2025-10-23', '2025-10-24'],
#               dtype='datetime64[ns]', name='Date', length=2468, freq=None)

# %% [markdown]
# # End
